# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pipeline import BuildDataset
from data import AudioVideo
from segmentor import Segmentor
import pickle
from utils import unpickle

# %%
best = '4566c335e71f215a1110a36a7cfec1882c86f86dbb7e3e5787dfdc26'
path_video = '/Users/aziai/Downloads/movies_casino_royale_2006_kissing_2.mp4'

# %%
# from moviepy.editor import VideoFileClip, concatenate_videoclips
# clip1 = VideoFileClip('/Users/aziai/Downloads/movies_casino_royale_2006_kissing_2.mp4')
# clip2 = VideoFileClip("/Users/aziai/Downloads/movies_casino_royale_2006_not_2.mp4")
# final_clip = concatenate_videoclips([clip1,clip2])
# final_clip.write_videofile("q.mp4")

# %%
model, _, _ = unpickle(f'results/{best}_experiment_results.pkl')

# %%
seg = Segmentor(model, min_frames=10, threshold=0.7)

# %% [markdown]
# ### Segment & viz

# %%
seg.visualize_segments('q.mp4')
# Out:
# Something went wrong!
# chunk:  21%|██        | 311/1479 [00:00<00:00, 3105.21it/s, now=None]
# MoviePy - Writing audio in %s
# MoviePy - Done.
# Found 1 segments
# Segment 1, 64 seconds
# First 10
# 10 random shots
# Last 10
# ...

# %% [markdown]
# ### YouTube

# %%
youtube_id = 'mq1VASjQipY'  # 'oQ6aHTngQEg'

# %%
# !ls -lht *.mp4
# Out:
# -rw-r--r--@ 1 aziai  staff   4.7M Jun  3 09:34 Inception Kiss Scene (HD).mp4
# -rw-r--r--@ 1 aziai  staff    19M Jun  2 23:44 q.mp4

# %%
yt = YouTube(f'http://youtube.com/watch?v={youtube_id}')
print(f'Title: {yt.title}')
yt_stream = yt.streams.first()
# Out:
# Title: Hot Summer Nights - Kiss Scene (Maika Monroe and Timothee Chalamet)

# %%
yt_stream.default_filename
# Out:
# 'Hot Summer Nights - Kiss Scene (Maika Monroe and Timothee Chalamet).mp4'

# %%
yt_stream.download()
# Out:
# '/Users/aziai/Dropbox/github/cs231n-project/Hot Summer Nights - Kiss Scene (Maika Monroe and Timothee Chalamet).mp4'

# %%
# !ls -lht *.mp4
# Out:
# -rw-r--r--@ 1 aziai  staff   2.0M Jun  3 10:02 Hot Summer Nights - Kiss Scene (Maika Monroe and Timothee Chalamet).mp4
# -rw-r--r--@ 1 aziai  staff   4.7M Jun  3 09:34 Inception Kiss Scene (HD).mp4
# -rw-r--r--@ 1 aziai  staff    19M Jun  2 23:44 q.mp4

# %%
seg.visualize_segments_youtube('GG5HmLQ_Fx0')
# Out:
# Title: Hot Summer Nights - Kiss Scene (Maika Monroe and Timothee Chalamet)
# Something went wrong!
# chunk:  23%|██▎       | 204/896 [00:00<00:00, 2015.71it/s, now=None]
# MoviePy - Writing audio in %s
# MoviePy - Done.
# Found 1 segments
# Segment 1, 42 seconds
# First 10
# 10 random shots
# Last 10
# ...

# %%
seg.visualize_segments_youtube('UgkOC2_qmuk')
# Out:
# Title: The Last Summer / Kiss Scene (KJ Apa and Maia Mitchell)
# chunk:   0%|          | 0/2018 [00:00<?, ?it/s, now=None]
# Something went wrong!
# MoviePy - Writing audio in %s
# MoviePy - Done.
# Found 1 segments
# Segment 1, 95 seconds
# First 10
# 10 random shots
# Last 10
# ...

# %%
seg.visualize_segments_youtube('oQ6aHTngQEg')
# Out:
# Title: Inception Kiss Scene (HD)
# Something went wrong!
# chunk:  33%|███▎      | 255/783 [00:00<00:00, 2541.44it/s, now=None]
# MoviePy - Writing audio in %s
# MoviePy - Done.
# Found 0 segments

# %%
seg.visualize_segments_youtube('mq1VASjQipY')
# Out:
# Title: Emma Watson Kissing Scene in Noah
# chunk:   0%|          | 0/1457 [00:00<?, ?it/s, now=None]
# Something went wrong!
# MoviePy - Writing audio in %s
# MoviePy - Done.
# Found 1 segments
# Segment 1, 68 seconds
# First 10
# 10 random shots
# Last 10
# ...

# %%
seg.visualize_segments_youtube('LVLyo2fU4cE')
# Out:
# Title: President Donald Trump and First Lady Melania Meet Officials Inside Clarence House
# Something went wrong!
# chunk:  18%|█▊        | 256/1438 [00:00<00:00, 2554.38it/s, now=None]
# MoviePy - Writing audio in %s
# MoviePy - Done.
# Found 1 segments
# Segment 1, 11 seconds
# First 10
# 10 random shots
# Last 10
# ...

# %%
seg.visualize_segments_youtube('2bVik34nWws')
# Out:
# Title: Black Mirror: Season 5 | Official Trailer | Netflix
# Something went wrong!
# chunk:   9%|▊         | 202/2366 [00:00<00:01, 2017.95it/s, now=None]
# MoviePy - Writing audio in %s
# MoviePy - Done.
# Found 2 segments
# Segment 1, 63 seconds
# First 10
# 10 random shots
# Last 10
# ...
# Segment 2, 16 seconds
# First 10
# 10 random shots
# Last 10
# ...

# %%
seg.visualize_segments_youtube('deSUQ7mZfWk')
# Out:
# Title: Westworld III - HBO 2020
# Something went wrong!
# MoviePy - Writing audio in %s
# MoviePy - Done.
# Found 3 segments
# Segment 1, 11 seconds
# First 10
# 10 random shots
# Last 10
# ...
# Segment 2, 10 seconds
# First 10
# 10 random shots
# Last 10
# ...
# Segment 3, 37 seconds
# First 10
# 10 random shots
# Last 10
# ...

# %%
seg.visualize_segments_youtube('mR6Y9j1EdHI')
# Out:
# Title: Highlights | Round 2 | The Memorial 2019
# Something went wrong!
# chunk:   4%|▍         | 150/3449 [00:00<00:02, 1496.66it/s, now=None]
# MoviePy - Writing audio in %s
# MoviePy - Done.
# Found 0 segments
